# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MachineLearning/Assignment7/PlayTennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df_encoded = df.copy()

# %%
for column in df_encoded.columns:
    df_encoded[column] = label_encoder.fit_transform(df_encoded[column])

# Separate features and target variable
X = df_encoded.drop('play', axis=1)
y = df_encoded['play']

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(criterion='entropy', random_state=42)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
# Visualize the tree
dot_data = export_graphviz(clf, out_file=None, feature_names=['outlook', 'temp', 'humidity', 'windy'], class_names=['no', 'yes'], filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph
